# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\vagdevi\anaconda3\lib\site-packages (4.21.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\vagdevi\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\vagdevi\anaconda3\lib\site-packages (from selenium) (0.25.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\vagdevi\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\vagdevi\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\vagdevi\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\vagdevi\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\vagdevi\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\vagdevi\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\vagdevi\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install selenium pandas
# Out:
# Requirement already satisfied: selenium in c:\users\vagdevi\anaconda3\lib\site-packages (4.21.0)
# Requirement already satisfied: pandas in c:\users\vagdevi\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\vagdevi\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\vagdevi\anaconda3\lib\site-packages (from selenium) (0.25.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\vagdevi\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\vagdevi\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\vagdevi\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vagdevi\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vagdevi\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vagdevi\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\vagdevi\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\vagdevi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\vagdevi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\vagdevi\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\vagdevi\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\vagdevi\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\vagdevi\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chromedriver-autoinstaller
# Out:
# Requirement already satisfied: chromedriver-autoinstaller in c:\users\vagdevi\anaconda3\lib\site-packages (0.6.4)
# Requirement already satisfied: packaging>=23.1 in c:\users\vagdevi\anaconda3\lib\site-packages (from chromedriver-autoinstaller) (23.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import chromedriver_autoinstaller

# %%
chromedriver_autoinstaller.install()

url = 'https://www.newyorkfed.org/markets/reference-rates/effr'

# Start ChromeDriver
driver = webdriver.Chrome()
driver.get(url)

# %%
chromedriver_autoinstaller.install()

# Set up the driver
driver = webdriver.Chrome()

# Navigate to the URL
url = 'https://www.newyorkfed.org/markets/reference-rates/effr'
driver.get(url)

time.sleep(5)

# %%
table = driver.find_element(By.TAG_NAME, 'table')

# Extract table rows and columns
rows = table.find_elements(By.TAG_NAME, 'tr')

# %%
# Loop through rows and get cell data
table_data = []
for row in rows:
    # Get columns in each row
    cols = row.find_elements(By.TAG_NAME, 'td')
    cols = [col.text for col in cols]
    table_data.append(cols)

# Convert data to DataFrame for easier manipulation
df = pd.DataFrame(table_data)

# Close the driver
driver.quit()

# Display the extracted table
df
# Out:
#         0     1     2     3     4     5     6            7
# 0    None  None  None  None  None  None  None         None
# 1   10/22  4.83  4.81  4.83  4.84  4.85    98  4.75 - 5.00
# 2   10/21  4.83  4.81  4.83  4.84  4.85    96  4.75 - 5.00
# 3   10/18  4.83  4.81  4.83  4.84  4.85    98  4.75 - 5.00
# 4   10/17  4.83  4.81  4.83  4.84  4.85    96  4.75 - 5.00
# 5   10/16  4.83  4.81  4.83  4.84  4.85    97  4.75 - 5.00
# 6   10/15  4.83  4.81  4.83  4.84  4.85    91  4.75 - 5.00
# 7   10/11  4.83  4.81  4.82  4.84  4.85    94  4.75 - 5.00
# 8   10/10  4.83  4.81  4.82  4.84  4.85    98  4.75 - 5.00
# 9   10/09  4.83  4.81  4.83  4.84  4.85    94  4.75 - 5.00
# 10  10/08  4.83  4.81  4.83  4.84  4.85    90  4.75 - 5.00
# 11  10/07  4.83  4.81  4.83  4.84  4.85    86  4.75 - 5.00
# 12  10/04  4.83  4.81  4.83  4.84  4.85    84  4.75 - 5.00
# 13  10/03  4.83  4.81  4.83  4.84  4.85    81  4.75 - 5.00
# 14  10/02  4.83  4.81  4.83  4.84  4.85    81  4.75 - 5.00
# 15  10/01  4.83  4.81  4.83  4.84  4.85    85  4.75 - 5.00
# 16  09/30  4.83  4.80  4.82  4.84  4.95    73  4.75 - 5.00
# 17  09/27  4.83  4.81  4.82  4.84  4.86    94  4.75 - 5.00
# 18  09/26  4.83  4.81  4.82  4.84  4.85   100  4.75 - 5.00
# 19  09/25  4.83  4.81  4.82  4.83  4.85   103  4.75 - 5.00
# 20  09/24  4.83  4.81  4.82  4.84  4.85    94  4.75 - 5.00
# 21  09/23  4.83  4.81  4.82  4.84  4.92    95  4.75 - 5.00
# 22  09/20  4.83  4.81  4.82  4.84  4.95    93  4.75 - 5.00
# 23  09/19  4.83  4.81  4.82  4.84  4.95    90  4.75 - 5.00
# 24  09/18  5.33  5.31  5.32  5.33  5.40   102  5.25 - 5.50
# 25  09/17  5.33  5.31  5.32  5.33  5.35   103  5.25 - 5.50
